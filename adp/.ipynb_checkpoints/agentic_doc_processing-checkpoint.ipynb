# %% [markdown]
# # Agentic Document Processing Pipeline Research Notebook

# %% [markdown]
# ## Phase 1:: Exploring processing with just OCR
# ### Objectives:
#     - parsing and extracting information from the document
#     - building an agent equipped with OCR tool
#
#     * Limitations:
#     OCR converts pixels to text. OCR alone produces raw text, however without context, syntax and information coherence.

# %%
# Needed Libraries
# Pillow (PIL): Load and manipulate images
# Pytesseract: Python wrapper for Tesseract OCR engine
# LangChain: Framework for building tool-enabled LLM applications
# Langgraph: for building graph-based agents


from PIL import Image
import pytesseract

from langchain_ollama.client import OllamaClient
from langgraph.graph
